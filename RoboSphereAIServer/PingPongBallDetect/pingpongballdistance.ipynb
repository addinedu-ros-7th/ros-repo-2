# %%
import cv2
from ultralytics import YOLO

# YOLO 모델 로드
model = YOLO('/home/kjj73/dev_ws/Project/final_project/best.pt')  # YOLO 가중치 파일 경로

# 카메라 초기화
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

# 탁구공 실제 지름 (단위: mm)
REAL_DIAMETER = 40

# 초점 거리 (실험적으로 계산된 값)
FOCAL_LENGTH = 687.5  # 초기값

while True:
    ret, frame = cap.read()
    if not ret:
        print("프레임을 가져올 수 없습니다.")
        break

    # YOLO 모델로 객체 감지
    results = model(frame)

    # 프레임에 감지 결과 시각화
    annotated_frame = results[0].plot()

    for result in results[0].boxes:  # 감지된 객체 반복
        box = result.xyxy[0]  # 경계 상자 좌표
        x1, y1, x2, y2 = map(int, box[:4])

        # 중심 좌표 계산
        x_center = int((x1 + x2) / 2)
        y_center = int((y1 + y2) / 2)

        # 픽셀 너비 계산
        pixel_width = x2 - x1

        # 거리 계산
        if pixel_width > 0:
            distance = (FOCAL_LENGTH * REAL_DIAMETER) / pixel_width
        else:
            distance = -1  # 유효하지 않은 경우

        # 좌표, 픽셀 너비 및 거리 출력
        label1 = f"Coord: ({x_center}, {y_center})"
        label2 = f"Width: {pixel_width}px"
        label3 = f"Dist: {distance:.2f}mm"
        cv2.circle(annotated_frame, (x_center, y_center), 5, (0, 0, 255), -1)  # 중심점 표시

        cv2.putText(annotated_frame, label3, (x1+5, y1 + 35), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
        cv2.putText(annotated_frame, label1, (x1+5, y1 + 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
        cv2.putText(annotated_frame, label2, (x1+5, y1 + 55), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
        
        cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)  # 경계 상자 표시

    # 결과 표시
    cv2.imshow("Ping Pong Ball Detection", annotated_frame)

    # 'q' 키를 누르면 종료
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 자원 해제
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 3.7ms
# Speed: 1.4ms preprocess, 3.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 2.4ms preprocess, 5.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 4.3ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.9ms
# Speed: 1.6ms preprocess, 3.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 3.0ms preprocess, 7.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.9ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 3.2ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 3.0ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.4ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.8ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 6.7ms
# Speed: 2.5ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 (no detections), 3.7ms
# Speed: 1.8ms preprocess, 3.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 1 oball, 4.2ms
# Speed: 1.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 1 oball, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 26, 거리 계산: 6730.77mm
#
# 0: 480x640 1 oball, 4.4ms
# Speed: 2.1ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 1 oball, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 1 oball, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 1 oball, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 2.5ms preprocess, 6.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 1 oball, 7.2ms
# Speed: 4.3ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 2 oballs, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 3 oballs, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 4.9ms
# Speed: 2.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 1 oball, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 2 oballs, 5.2ms
# Speed: 2.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 4.9ms
# Speed: 2.0ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 2 oballs, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 3 oballs, 8.0ms
# Speed: 3.2ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 4.8ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.2ms preprocess, 5.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 oballs, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 2 oballs, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 12, 거리 계산: 14583.33mm
#
# 0: 480x640 2 oballs, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
#
# 0: 480x640 1 oball, 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 18, 거리 계산: 9722.22mm
#
# 0: 480x640 4 oballs, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 114, 거리 계산: 1535.09mm
# 픽셀 너비: 29, 거리 계산: 6034.48mm
# 픽셀 너비: 26, 거리 계산: 6730.77mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
#
# 0: 480x640 3 oballs, 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
#
# 0: 480x640 2 oballs, 4.9ms
# Speed: 2.3ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
#
# 0: 480x640 1 oball, 5.7ms
# Speed: 2.7ms preprocess, 5.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 13, 거리 계산: 13461.54mm
#
# 0: 480x640 2 oballs, 5.0ms
# Speed: 2.5ms preprocess, 5.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 26, 거리 계산: 6730.77mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 26, 거리 계산: 6730.77mm
#
# 0: 480x640 2 oballs, 6.3ms
# Speed: 2.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 12, 거리 계산: 14583.33mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 5.3ms
# Speed: 2.4ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 14, 거리 계산: 12500.00mm
# 픽셀 너비: 12, 거리 계산: 14583.33mm
#
# 0: 480x640 3 oballs, 6.0ms
# Speed: 2.6ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 2 oballs, 6.6ms
# Speed: 3.3ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 13, 거리 계산: 13461.54mm
# 픽셀 너비: 13, 거리 계산: 13461.54mm
#
# 0: 480x640 1 oball, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 15, 거리 계산: 11666.67mm
#
# 0: 480x640 2 oballs, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
#
# 0: 480x640 2 oballs, 7.9ms
# Speed: 3.4ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 27, 거리 계산: 6481.48mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
#
# 0: 480x640 2 oballs, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 12, 거리 계산: 14583.33mm
#
# 0: 480x640 3 oballs, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
#
# 0: 480x640 1 oball, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 13, 거리 계산: 13461.54mm
#
# 0: 480x640 2 oballs, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 27, 거리 계산: 6481.48mm
#
# 0: 480x640 2 oballs, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
#
# 0: 480x640 4 oballs, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 25, 거리 계산: 7000.00mm
# 픽셀 너비: 7, 거리 계산: 25000.00mm
#
# 0: 480x640 2 oballs, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 121, 거리 계산: 1446.28mm
#
# 0: 480x640 2 oballs, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 11, 거리 계산: 15909.09mm
# 픽셀 너비: 12, 거리 계산: 14583.33mm
#
# 0: 480x640 2 oballs, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 11, 거리 계산: 15909.09mm
#
# 0: 480x640 2 oballs, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.7ms
# Speed: 3.4ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 22, 거리 계산: 7954.55mm
#
# 0: 480x640 1 oball, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 4 oballs, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 70, 거리 계산: 2500.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
#
# 0: 480x640 3 oballs, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 63, 거리 계산: 2777.78mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 4 oballs, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 131, 거리 계산: 1335.88mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 87, 거리 계산: 2011.49mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 1 oball, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 4 oballs, 4.6ms
# Speed: 1.9ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 43, 거리 계산: 4069.77mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 4 oballs, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 36, 거리 계산: 4861.11mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 31, 거리 계산: 5645.16mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.4ms
# Speed: 2.8ms preprocess, 5.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.9ms
# Speed: 1.8ms preprocess, 5.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.1ms
# Speed: 2.9ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.5ms
# Speed: 2.0ms preprocess, 4.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 2.1ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 4.8ms
# Speed: 1.6ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.3ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 2.7ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.8ms
# Speed: 1.5ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 4.4ms
# Speed: 2.2ms preprocess, 4.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 24, 거리 계산: 7291.67mm
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.0ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 2.1ms preprocess, 4.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 2.8ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.8ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.4ms preprocess, 4.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 4.1ms preprocess, 5.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 oball, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 (no detections), 3.7ms
# Speed: 1.6ms preprocess, 3.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 oballs, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 19, 거리 계산: 9210.53mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 4.4ms
# Speed: 1.1ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 27, 거리 계산: 6481.48mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 9.1ms
# Speed: 4.9ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 26, 거리 계산: 6730.77mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 29, 거리 계산: 6034.48mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 oballs, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 44, 거리 계산: 3977.27mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 49, 거리 계산: 3571.43mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 2 oballs, 5.8ms
# Speed: 3.9ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 3.9ms
# Speed: 1.6ms preprocess, 3.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 4.7ms
# Speed: 2.4ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 5.1ms
# Speed: 1.8ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 5.7ms
# Speed: 3.2ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 4.4ms
# Speed: 1.7ms preprocess, 4.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 1 oball, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 6.0ms
# Speed: 3.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 5.3ms
# Speed: 2.2ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 6.6ms
# Speed: 3.4ms preprocess, 6.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
#
# 0: 480x640 1 oball, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
#
# 0: 480x640 1 oball, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 2 oballs, 6.3ms
# Speed: 4.5ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.6ms
# Speed: 2.0ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
#
# 0: 480x640 2 oballs, 4.9ms
# Speed: 1.9ms preprocess, 4.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 4.9ms
# Speed: 1.7ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 2 oballs, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 5.6ms
# Speed: 1.7ms preprocess, 5.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 7.9ms
# Speed: 4.7ms preprocess, 7.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 5.6ms
# Speed: 1.9ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.0ms
# Speed: 2.5ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 2 oballs, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.2ms
# Speed: 3.6ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 2 oballs, 6.0ms
# Speed: 3.1ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 2 oballs, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 4.5ms
# Speed: 1.2ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 4.8ms
# Speed: 1.7ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 3.9ms
# Speed: 1.1ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 1 oball, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 2 oballs, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 1 oball, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 3.9ms
# Speed: 1.4ms preprocess, 3.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 53, 거리 계산: 3301.89mm
#
# 0: 480x640 1 oball, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 3.7ms
# Speed: 1.2ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
#
# 0: 480x640 2 oballs, 4.5ms
# Speed: 1.6ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
#
# 0: 480x640 2 oballs, 3.7ms
# Speed: 1.5ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
#
# 0: 480x640 1 oball, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 1 oball, 4.2ms
# Speed: 1.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 2 oballs, 4.6ms
# Speed: 2.2ms preprocess, 4.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.4ms
# Speed: 2.4ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.1ms
# Speed: 2.0ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 2 oballs, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.9ms
# Speed: 1.6ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 2 oballs, 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
#
# 0: 480x640 2 oballs, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.7ms
# Speed: 1.7ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 54, 거리 계산: 3240.74mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 1 oball, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
#
# 0: 480x640 3 oballs, 4.7ms
# Speed: 1.9ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 10, 거리 계산: 17500.00mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.2ms
# Speed: 1.6ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 3.9ms
# Speed: 1.4ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.7ms
# Speed: 1.2ms preprocess, 3.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
#
# 0: 480x640 2 oballs, 3.7ms
# Speed: 1.4ms preprocess, 3.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.2ms
# Speed: 1.4ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 3.8ms
# Speed: 1.4ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.3ms
# Speed: 1.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.6ms
# Speed: 1.2ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.5ms
# Speed: 1.4ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.0ms
# Speed: 1.6ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.1ms
# Speed: 1.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.4ms
# Speed: 1.7ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.7ms
# Speed: 1.2ms preprocess, 3.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 4 oballs, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 4.4ms
# Speed: 1.1ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 4.3ms
# Speed: 1.4ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.7ms
# Speed: 1.3ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 2 oballs, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.7ms
# Speed: 1.8ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.5ms
# Speed: 1.5ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.3ms
# Speed: 2.0ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 9, 거리 계산: 19444.44mm
#
# 0: 480x640 3 oballs, 3.7ms
# Speed: 1.1ms preprocess, 3.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 56, 거리 계산: 3125.00mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.4ms
# Speed: 1.5ms preprocess, 4.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 6.5ms
# Speed: 3.4ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.7ms
# Speed: 1.4ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 4.5ms
# Speed: 1.1ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 2 oballs, 4.4ms
# Speed: 2.0ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
#
# 0: 480x640 3 oballs, 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 3 oballs, 3.9ms
# Speed: 2.0ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 23, 거리 계산: 7608.70mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 4 oballs, 11.3ms
# Speed: 2.8ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 12, 거리 계산: 14583.33mm
#
# 0: 480x640 3 oballs, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
#
# 0: 480x640 4 oballs, 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 픽셀 너비: 55, 거리 계산: 3181.82mm
# 픽셀 너비: 8, 거리 계산: 21875.00mm
# 픽셀 너비: 22, 거리 계산: 7954.55mm
# ...
#
# 0: 480x640 (no detections), 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.3ms
# Speed: 2.8ms preprocess, 11.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.8ms preprocess, 4.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.8ms
# Speed: 1.5ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.5ms
# Speed: 1.6ms preprocess, 3.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 3.1ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.8ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 6.7ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 4.0ms preprocess, 8.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.7ms
# Speed: 1.6ms preprocess, 19.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 4.4ms preprocess, 7.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 3.8ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 4.4ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 4.2ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 2.1ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 4.2ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 1.7ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 4.3ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 4.7ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 7.2ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.4ms
# Speed: 4.8ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 13.4ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 3.0ms preprocess, 4.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 2.2ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.4ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 4.5ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.5ms preprocess, 4.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 2.1ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 4.1ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.3ms preprocess, 7.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.5ms preprocess, 7.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 3.6ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 3.3ms preprocess, 5.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 2.9ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.4ms
# Speed: 5.6ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 5.3ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.9ms
# Speed: 12.3ms preprocess, 16.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 3.4ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 3.5ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 3.7ms preprocess, 7.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.7ms
# Speed: 4.0ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.8ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.8ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 2.4ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.4ms
# Speed: 3.0ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.4ms
# Speed: 3.2ms preprocess, 28.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 3.4ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.8ms
# Speed: 5.5ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 4.0ms preprocess, 13.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 8.2ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.5ms
# Speed: 2.6ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 3.4ms preprocess, 12.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 3.1ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 3.3ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 4.1ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 3.4ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 3.6ms preprocess, 5.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 2.0ms preprocess, 4.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
